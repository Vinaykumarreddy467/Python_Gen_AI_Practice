# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import  numpy as np
data=np.random.rand(2,3,4)
data
# Out:
# array([[[0.51268849, 0.39458444, 0.97201078, 0.08253488],
#         [0.02615405, 0.86402946, 0.98085432, 0.62244792],
#         [0.35282972, 0.01554541, 0.97197335, 0.98135831]],
#
#        [[0.83331892, 0.45621921, 0.7023945 , 0.99692884],
#         [0.99869446, 0.74644152, 0.90799253, 0.86225902],
#         [0.00428631, 0.73263791, 0.3939247 , 0.72750516]]])

# %%
print(data.shape)
# Out:
# (2, 3, 4)
