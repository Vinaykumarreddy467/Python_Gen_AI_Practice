# %%
from dotenv import load_dotenv
from elevenlabs.client import ElevenLabs
from elevenlabs.play import play
import os

load_dotenv()

elevenlabs = ElevenLabs(
  api_key=os.getenv("ELEVENLABS_API_KEY"),
)

audio = elevenlabs.text_to_speech.convert(
    text="The first move is what sets everything in motion. hi, vinay, how are you doing?.",
    voice_id="JBFqnCBsd6RMkjVDRZzb",  # "George" - browse voices at elevenlabs.io/app/voice-library
    model_id="eleven_v3",
    output_format="mp3_44100_128",
)

play(audio)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[1], line 19
#       8 elevenlabs = ElevenLabs(
#       9   api_key=os.getenv("sk_4114bea6ff599daf9f8c900b8daa8f01725b94632f41f7d6"),
#      10 )
#      12 audio = elevenlabs.text_to_speech.convert(
#      13     text="The first move is what sets everything in motion. hi, vinay, how are you doing?.",
#      14     voice_id="JBFqnCBsd6RMkjVDRZzb",  # "George" - browse voices at elevenlabs.io/app/voice-library
#      15     model_id="eleven_v3",
#      16     output_format="mp3_44100_128",
#      17 )
# ---> 19 play(audio)
#
# File ~/anaconda3/lib/python3.13/site-packages/elevenlabs/play.py:19, in play(audio, notebook, use_ffmpeg)
#      13 def play(
#      14     audio: Union[bytes, Iterator[bytes]],
#      15     notebook: bool = False,
#      16     use_ffmpeg: bool = True
#      17 ) -> None:
#      18     if isinstance(audio, Iterator):
# ---> 19         audio = b"".join(audio)
#      20     if notebook:
#      21         try:
#
# File ~/anaconda3/lib/python3.13/site-packages/elevenlabs/text_to_speech/client.py:157, in TextToSpeechClient.convert(self, voice_id, text, enable_logging, optimize_streaming_latency, output_format, model_id, language_code, voice_settings, pronunciation_dictionary_locators, seed, previous_text, next_text, previous_request_ids, next_request_ids, use_pvc_as_ivc, apply_text_normalization, apply_language_text_normalization, request_options)
#      48 def convert(
#      49     self,
#      50     voice_id: str,
#    (...)     70     request_options: typing.Optional[RequestOptions] = None,
#      71 ) -> typing.Iterator[bytes]:
#      72     """
#      73     Converts text into speech using a voice of your choice and returns audio.
#      74
#    (...)    155     )
#     156     """
# --> 157     with self._raw_client.convert(
#     158         voice_id,
#     159         text=text,
#     160         enable_logging=enable_logging,
#     161         optimize_streaming_latency=optimize_streaming_latency,
#     162         output_format=output_format,
#     163         model_id=model_id,
#     164         language_code=language_code,
#     165         voice_settings=voice_settings,
#     166         pronunciation_dictionary_locators=pronunciation_dictionary_locators,
#     167         seed=seed,
#     168         previous_text=previous_text,
#     169         next_text=next_text,
#     170         previous_request_ids=previous_request_ids,
#     171         next_request_ids=next_request_ids,
#     172         use_pvc_as_ivc=use_pvc_as_ivc,
#     173         apply_text_normalization=apply_text_normalization,
#     174         apply_language_text_normalization=apply_language_text_normalization,
#     175         request_options=request_options,
#     176     ) as r:
#     177         yield from r.data
#
# File ~/anaconda3/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.13/site-packages/elevenlabs/text_to_speech/raw_client.py:212, in RawTextToSpeechClient.convert(self, voice_id, text, enable_logging, optimize_streaming_latency, output_format, model_id, language_code, voice_settings, pronunciation_dictionary_locators, seed, previous_text, next_text, previous_request_ids, next_request_ids, use_pvc_as_ivc, apply_text_normalization, apply_language_text_normalization, request_options)
#     204         raise ParsingError(
#     205             status_code=_response.status_code,
#     206             headers=dict(_response.headers),
#     207             body=_response.json(),
#     208             cause=e,
#     209         )
#     210     raise ApiError(status_code=_response.status_code, headers=dict(_response.headers), body=_response_json)
# --> 212 yield _stream()
#
# File ~/anaconda3/lib/python3.13/site-packages/elevenlabs/text_to_speech/raw_client.py:210, in RawTextToSpeechClient.convert.<locals>._stream()
#     203 except ValidationError as e:
#     204     raise ParsingError(
#     205         status_code=_response.status_code,
#     206         headers=dict(_response.headers),
#     207         body=_response.json(),
#     208         cause=e,
#     209     )
# --> 210 raise ApiError(status_code=_response.status_code, headers=dict(_response.headers), body=_response_json)
#
# ApiError: headers: {'date': 'Mon, 27 Jul 2026 05:11:13 GMT', 'server': 'uvicorn', 'content-length': '229', 'content-type': 'application/json', 'vary': 'Accept-Language', 'access-control-allow-origin': '*', 'access-control-allow-headers': '*', 'access-control-allow-methods': 'POST, PATCH, OPTIONS, DELETE, GET, PUT', 'access-control-max-age': '600', 'strict-transport-security': 'max-age=1800;', 'x-trace-id': '842bc236614975426a362bb245d6c8c0', 'x-region': 'asia-southeast1', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'}, status_code: 401, body: {'detail': {'type': 'authentication_error', 'code': 'unauthorized', 'message': 'Neither authorization header nor xi-api-key received, please provide one.', 'status': 'needs_authorization', 'request_id': '842bc236614975426a362bb245d6c8c0'}}
