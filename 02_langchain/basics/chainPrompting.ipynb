# %%
import os
import logging
from openai import OpenAI

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

client = OpenAI(
    base_url="http://localhost:11434/v1",  
    api_key="ollama",                      
)

logger.info("Ollama local client connected successfully")

topic=(input("enter any topic: "))
output = client.chat.completions.create(
    model="llama3.2:3b",               
    messages=[
            {"role": "system", "content": "You are a helpful assistant that you help to the user to understand any topics in short form like 50 words or less"},
            {"role": "user",  "content": topic
            }
        ],
    )
print(output)

# %%
import os
import logging
from openai import OpenAI

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

client = OpenAI(
    base_url="http://localhost:11434/v1",  
    api_key="ollama",                      
)

logger.info("Ollama local client connected successfully")

topic=(input("enter any topic: "))
output = client.chat.completions.create(
    model="llama3.2:3b",               
    messages=[
            {"role": "system", "content": "You are a helpful assistant that you help to the user to understand any topics in short form like 50 words or less"},
            {"role": "user",  "content": topic
            }
        ],
    )
# Store the response content in output2 for use in other cells
output2 = output.choices[0].message.content
print(output2)

# %%
output1=output.choices[0].message.content
output1

# %%
import os
import logging
from openai import OpenAI

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

client = OpenAI(
    base_url="http://localhost:11434/v1",  
    api_key="ollama",                      
)

logger.info("Ollama local client connected successfully")

output2 = client.chat.completions.create(
    model="phi3:latest",   
    messages=[
            {"role": "system", "content": "You are a highly concise assistant. Summarize all user requests in exactly 50 words or less while maintaining the core message, actionable details, and key takeaways."},
            {"role": "user",  "content": output1
            }
        ],
    )
print(output2)

# %%
output2

# %%
# Print the contents of output2 variable to display its value
print(output2.choices[0].message.content)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_ollama import ChatOllama

# 1. Define your prompt structure
topic="hobbies"
audience="10th class students"
prompt = f"Explain the concept of {topic} to a {audience} in exactly two sentences."



# 2. Setup your Qwen model (Ensure base_url stops at port 11434)
llm = ChatOllama(
    model="qwen3-vl:2b", 
    base_url="http://localhost:11434/v1",
    messages=[
        {"role":"system", "context" : "you are a professional assistant {audience} and you explain everything in simple terms in 3 lines."},
        {"role":"user"  ,  "context" : prompt}
    ],
)

# 3. Create the execution chain
chain = prompt | llm

chain.invoke(prompts)
print(response.content)

# %%
#

# %%
from langchain_core.prompts import PromptTemplate
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="tinyllama:latest")

prompt = PromptTemplate(
    input_variables=["topic"],
    template="""
You are a helpful assistant.
Explain everything in 15 words or fewer.

Explain {topic} in simple terms.
"""
)

chain = prompt | llm

results = chain.batch([
    {"topic": "Python"},
    {"topic": "java"},
    {"topic": "pineapple"}
])

for result in results:
    print(result)
    print()
# Out:
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="qwen3-vl:2b")

prompt = PromptTemplate(
    input_variables=["topic"],
    template="""
You are a helpful assistant.
Explain everything in 15 words or fewer.

Explain {topic} in simple terms.
"""
)

chain = prompt | llm
topics=["python","java","c++","c language","himalayas"]
batch=2
for top in range(1,leng(topics),batch):
    if top<len(topics):
        results = chain.batch([
            {"topic": }
        ])

for result in results:
    print(result)
