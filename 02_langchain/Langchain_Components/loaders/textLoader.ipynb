# %%
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import TextLoader
from langchain_core.prompts import PromptTemplate
#from langchain_core.output_parsers import StringOutputParser


from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
#from langchain_ollama import ChatOllama  # Requires: pip install langchain-openai

# Load environment variables (like OPENAI_API_KEY)
load_dotenv()

# Initialize the LLM
llm= ChatGroq(
    model="llama-3.3-70b-versatile", # You can also use mixtral-8x7b-32768
    temperature=0.5
)


# Define the prompt template
prompt = PromptTemplate(
    template="Write a summary for the following poem:\n{poem}", 
    input_variables=['poem']
)

# Define the output parser
parser = StrOutputParser()

# Load the document
loader = TextLoader('cricket.txt', encoding='utf-8')
docs = loader.load()

# %%
print(type(docs))
# Out:
# <class 'list'>

# %%
print(len(docs))
# Out:
# 1

# %%
print(docs[0].page_content[:500])
# Out:
# Beneath the sun or floodlight's gleam,
#
# Cricket lives like a waking dream.
#
# A field of green, a willowed sound,
#
# Where legends rise and tales are found.
#
# From dusty lanes where barefoot boys,
#
# Chase every run with shrieks of joy,
#
# To packed arenas roaring loud,
#
# The game unites a global crowd.
#
# A coin is tossed, the captains stare,
#
# As tension thickens in the air.
#
# Bat or bowl? A choice so bold,
#
# A story new begins, retold.
#
# The openers walk, calm yet brave,
#
# Each stride a wave upon the wave.
#
# T

# %%
print(docs[0].metadata)
# Out:
# {'source': 'cricket.txt'}

# %%
# Create the chain using LangChain Expression Language (LCEL)
chain = prompt | llm | parser

# %%
# Run the chain by passing the content of the text file
poem_content = docs[0].page_content
summary = chain.invoke({"poem": poem_content})

print(summary)
# Out:
# The poem is a beautiful and detailed tribute to the sport of cricket, describing its magic, charm, and ability to unite people across the globe. It vividly portrays the sights, sounds, and emotions of the game, from the thrill of a perfectly executed shot to the agony of a batsman's dismissal. The poem explores the various aspects of cricket, including the strategies, skills, and sportsmanship involved, as well as the passion and dedication of its fans.
#
# The poem also delves into the history and culture of cricket, referencing legendary players and iconic venues, and highlighting the game's ability to transcend borders, cultures, and generations. It celebrates the joy, excitement, and sense of community that cricket brings to people's lives, and acknowledges the sport's power to inspire, to heal, and to bring people together.
#
# ...
