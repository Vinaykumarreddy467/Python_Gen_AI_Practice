# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()

# %%
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

# %%
res=llm.invoke("who is viekanadha")

# %%
res
# Out:
# AIMessage(content='I believe you are referring to Swami Vivekananda, a prominent Indian philosopher, yogi, and spiritual leader. He was born as Narendranath Datta on January 12, 1863, in Calcutta, India, and is best known for introducing the philosophies of Vedanta and Yoga to the Western world.\n\nSwami Vivekananda was a key figure in the Indian independence movement and a major influence on modern Hinduism. He was a disciple of Ramakrishna, a Indian mystic and saint, and after Ramakrishna\'s death, Vivekananda traveled to the United States and Europe, where he spread the teachings of Vedanta and Yoga.\n\nSome of his notable achievements and contributions include:\n\n1. **Representing Hinduism at the Parliament of the World\'s Religions (1893)**: Vivekananda\'s speech at the Parliament of the World\'s Religions in Chicago, Illinois, is considered a landmark event in the history of Hinduism. He introduced Hinduism to the Western world and emphasized the importance of tolerance and un
# ...

# %%
res.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 380,
#   'prompt_tokens': 41,
#   'total_tokens': 421,
#   'completion_time': 1.558608813,
#   'completion_tokens_details': None,
#   'prompt_time': 0.007641183,
#   'prompt_tokens_details': None,
#   'queue_time': 0.162438285,
#   'total_time': 1.566249996},
#  'model_name': 'llama-3.3-70b-versatile',
#  'system_fingerprint': 'fp_45180df409',
#  'service_tier': 'on_demand',
#  'finish_reason': 'stop',
#  'logprobs': None,
#  'model_provider': 'groq'}

# %%
res.tool_calls
# Out:
# []

# %%
# Create a message
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming.")
]

# %%
res= llm.invoke(messages)
res
# Out:
# AIMessage(content="J'adore la programmation.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 55, 'total_tokens': 64, 'completion_time': 0.036688591, 'completion_tokens_details': None, 'prompt_time': 0.002953026, 'prompt_tokens_details': None, 'queue_time': 0.055033703, 'total_time': 0.039641617}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f6438-1da2-7fb1-957a-471b9e530ce9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 55, 'output_tokens': 9, 'total_tokens': 64})

# %%
req=llm.invoke([("human", "I love programming.")])

# %%
req
# Out:
# AIMessage(content='Programming can be a fun and rewarding hobby or career. There are so many different areas to explore, from web development to artificial intelligence, and countless programming languages to learn. What type of programming do you enjoy most? Are you working on any projects or learning a new language?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 39, 'total_tokens': 95, 'completion_time': 0.184742146, 'completion_tokens_details': None, 'prompt_time': 0.001972214, 'prompt_tokens_details': None, 'queue_time': 0.050833155, 'total_time': 0.18671436}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f643a-e60f-7ac2-8185-03d6ef805042-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 56, 'total_tokens': 95})

# %%
req=llm.invoke([("I love programming.")])

# %%
req
# Out:
# AIMessage(content='Programming can be a fascinating and rewarding field, offering a wide range of creative and problem-solving opportunities. What kind of programming do you enjoy most? Are you interested in web development, mobile app development, artificial intelligence, or something else?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 39, 'total_tokens': 87, 'completion_time': 0.14456785, 'completion_tokens_details': None, 'prompt_time': 0.002942547, 'prompt_tokens_details': None, 'queue_time': 0.161831661, 'total_time': 0.147510397}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f643b-1f3e-7630-8310-5e8d75c67e0c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 48, 'total_tokens': 87})

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.6",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# KeyboardInterrupt

# %%
from langchain_ollama import ChatOllama

ollama= ChatOllama(
    model="phi3:latest",
    temperature=0,
    system="you are a helpful assistant accepts the user input in any language and responed only in hindi" 
)

# %%
res=ollama.invoke("do you know ")

# %%
print(res)
# Out:
# content="Why don't scientists trust atoms? Because they make up everything!" additional_kwargs={} response_metadata={'model': 'phi3:latest', 'created_at': '2026-07-16T05:05:07.153068939Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8402014384, 'load_duration': 87767739, 'prompt_eval_count': 18, 'prompt_eval_duration': 580456457, 'eval_count': 16, 'eval_duration': 7692630987, 'logprobs': None, 'model_name': 'phi3:latest', 'model_provider': 'ollama'} id='lc_run--019f6950-4f79-70d0-8e88-8d7223b8d60d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 16, 'total_tokens': 34}

# %%
res
# Out:
# AIMessage(content="Why don't scientists trust atoms? Because they make up everything!", additional_kwargs={}, response_metadata={'model': 'phi3:latest', 'created_at': '2026-07-16T05:05:07.153068939Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8402014384, 'load_duration': 87767739, 'prompt_eval_count': 18, 'prompt_eval_duration': 580456457, 'eval_count': 16, 'eval_duration': 7692630987, 'logprobs': None, 'model_name': 'phi3:latest', 'model_provider': 'ollama'}, id='lc_run--019f6950-4f79-70d0-8e88-8d7223b8d60d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 16, 'total_tokens': 34})

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

model= ChatGroq( model_name="llama-3.3-70b-versatile",temperature=0.7)
result=model.invoke("write a 5 lines poem on lost love")
print(result)
# Out:
# content="In memories, your smile remains,\nA bittersweet reminder of love in vain.\nMy heart, once full, now empty space,\nLonging for the touch of your gentle face,\nForever lost, our love's last refrain." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 44, 'total_tokens': 91, 'completion_time': 0.181465957, 'completion_tokens_details': None, 'prompt_time': 0.00123394, 'prompt_tokens_details': None, 'queue_time': 0.052871169, 'total_time': 0.182699897}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f6941-4a3c-7cf2-9030-914f4170de19-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 44, 'output_tokens': 47, 'total_tokens': 91}

# %%
from langchain_core.prompts import ChatPromptTemplate


chat_template = ChatPromptTemplate([
    ('system', 'You are a helpful {domain} expert.'),
    ('human', 'Explain in simple terms, what is {topic}?')
])

prompt_value = chat_template.invoke({'domain': 'philosophy', 'topic': 'trauma'})
print(prompt_value)
# Out:
# messages=[SystemMessage(content='You are a helpful philosophy expert.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain in simple terms, what is trauma?', additional_kwargs={}, response_metadata={})]

# %%
res=ollama.invoke(prompt_value)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessegesPlaceholder

chat_template=chatpromptTemplate([
    ('system','You are a helpful customer support agent'),
    MessegesPlaceholder(variable_name='chat_history'),
    ('human','{query}')
])
chat_history=[]
with open('chat_history.txt') as f:
    chat_history.extend(f.readlines())
print(chat_history)
prompt=chat_history.invoke({'chat_history':'chat_history'},{'query':"whwre is my refund"})
print(prompt)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

# 1. Define the template
chat_template = ChatPromptTemplate([
    ('system', 'You are a helpful customer support agent.'),
    MessagesPlaceholder(variable_name='chat_history'),
    ('human', '{query}')
])

# 2. Define the file saving function (Expects a string)
def add_into_file(query_text):
    with open('chat_history.txt', 'a') as f:
        f.write(query_text + '\n')  # Adds a newline so queries don't bunch up

# 3. Define your inputs (Simulating the user entering a query)
user_query = 'Where is my refund?'
chat_history = []  # Empty for now, or loaded from a file

# 4. Save the user query to the file immediately
add_into_file(user_query)

# 5. Invoke the template using your variables
prompt = chat_template.invoke({
    'chat_history': chat_history,  
    'query': user_query
})

# 6. Print the readable string version of the prompt object
print(prompt.to_string())
# Out:
# Current History: []
# messages=[SystemMessage(content='You are a helpful customer support agent.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Where is my refund?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder


chat_template = ChatPromptTemplate([
    ('system', 'You are a helpful customer support agent.'),
    MessagesPlaceholder(variable_name='chat_history'),
    ('human', '{query}')
])

def add_into_file(query_text):
    with open('chat_history.txt', 'a') as f:
        f.write(query_text + '\n')  
        
user_query = 'Where is my refund?'
chat_history =[]

try:
    with open('chat_history.txt', 'r') as f:
        for line in f:
            clean_line = line.strip()
            if clean_line:
                chat_history.append(('human', clean_line))
except FileNotFoundError:
    # Handles the case where the file doesn't exist yet
    pass


add_into_file(user_query)

prompt = chat_template.invoke({
    'chat_history': chat_history,  
    'query': user_query
})

print(chat_history)
print(prompt)
# Out:
# []
# messages=[SystemMessage(content='You are a helpful customer support agent.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Where is my refund?', additional_kwargs={}, response_metadata={})]

# %%
uv add pydantic
# Out:
# /home/mikealson/anaconda3/bin/python: No module named uv
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from typing import Optional, Literal
from pydantic import BaseModel, Field
from langchain_ollama import ChatOllama

load_dotenv()

llm= ChatOllama(
    model="phi3:latest",
    temperature=0.5,
    task="text generation"
)

# %%
class Review(BaseModel):

    key_themes: list[str] = Field(description="Write down all the key themes discussed in the review in a list")
    summary: str = Field(description="A brief summary of the review")
    sentiment: Literal["pos", "neg"] = Field(description="Return sentiment of the review either negative, positive or neutral")
    pros: Optional[list[str]] = Field(default=None, description="Write down all the pros inside a list")
    cons: Optional[list[str]] = Field(default=None, description="Write down all the cons inside a list")
    name: Optional[str] = Field(default=None, description="Write the name of the reviewer")
    

structured_model = llm.with_structured_output(Review)

# %%
result=structured_model.invoke("how are you doing bro what you can do for me")

# %%
result
# Out:
# Review(key_themes=['well-being', 'assistance'], summary="I'm here to help! How can I assist you today?", sentiment='pos', pros=None, cons=[], name=None)

# %%
result.summary
# Out:
# "I'm here to help! How can I assist you today?"

# %%
review = "I absolutely love this product! It works perfectly."
result = structured_model.invoke(f"Analyze the sentiment of this review: {review}")

# %%
result
# Out:
# Review(key_themes=['product', 'love'], summary='positive', sentiment='pos', pros=None, cons=[], name=None)

# %%
pip install grandalf

# %%
#simple chain example
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

prompt = PromptTemplate(
    template='Generate 5 interesting facts about {topic}', 
    input_variables=['topic'] 
)

# %%
llm= ChatOllama(
    model="phi3:latest",
    temperature=0.5,
    task="text generation"
)

# %%
parser=StrOutputParser()

# %%
chain =prompt| llm | parser

# %%
result=chain.invoke({'topic':'romance'})

# %%
print(result)
# Out:
# 1. Romantic love is not just a modern phenomenon; it has been celebrated in various cultures throughout history, often symbolized by the act of kissing as a form of expression and connection between lovers (Source: "The History of Love" by Nancy Friday).
# 2. Scientifically speaking, romantic attraction can be influenced by pheromones - chemical substances secreted from our bodies that we emit when aroused or stressed which play an important role in human sexual behavior and mate selection process (Source: National Geographic's "How Pheromones Work").
# 3. A study published in the Journal of Research in Personality found a strong correlation between physical attractiveness, specifically facial symmetry, being perceived as more romantically appealing to others (Source: “Facial Attractiveness and Physical Symmetry Predict Perceived Romantic Potential” by Shelley Taylor et al.).
# ...

# %%
chain.get_graph().print_ascii()
# Out:
#      +-------------+
#      | PromptInput |
#      +-------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#       +------------+
#       | ChatOllama |
#       +------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
