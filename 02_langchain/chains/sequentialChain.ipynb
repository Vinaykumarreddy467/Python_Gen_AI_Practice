# %%
#simple chain example
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate

from langchain_core.output_parsers import StrOutputParser

load_dotenv()

prompt1 = PromptTemplate(
    template='Generate 5 interesting facts about {topic}', 
    input_variables=['topic'] 
)

prompt2 = PromptTemplate(
    template='Generate a 5 point summary for the following facts about {topic}', 
    input_variables=['topic'] 
)

# %%
llm= ChatOllama(
    model="phi3:latest",
    temperature=0.5,
    task="text generation"
)

# %%
parser=StrOutputParser()

# %%
chain= prompt1 | llm | parser | prompt2 | llm | parser

# %%
result=chain.invoke({'topic':'dreams'})

# %%
result
# Out:
# '1. Dreaming occurs in all age groups, but the content of our dreams tends to change as we grow older - children often have simpler and more concrete themes while adults experience complex emotions and narratives within their dreams: This fact highlights how dream experiences evolve throughout different stages of life due to changes in cognitive abilities and personal growth. It also emphasizes that the content of our dreams is not fixed but can change based on age, maturity level, environment, etc.\n2. Lucid dreaming, where one is aware that they are dreaming, can be learned through practice - techniques such as reality checks during waking hours or maintaining a dream journal may help improve the frequency of lucid dreams: This fact shows how individuals have control over their own consciousness within sleep and highlights various methods to increase awareness in dream states. It also emphasizes that this skill can be learned through practice, thus opening up possibilities for personal growth and self-exploration during sleep.\n3. Some research suggests that people who have nightmares are more likely to be emotionally resilient - they tend to bounce back from difficult situations and show a greater ability in handling stressful events: This fact challenges the negative connotations associated with having frequent nightmares, suggesting instead that it can indicate emotional strength. It also highlights how dream experiences may reflect our coping mechanisms during waking hours, thus giving insight into personal resilience and adaptability to difficult situations.\n4. Studies have shown that dreaming may play an important role in memory consolidation - the brain sorts through information from our waking hours and organizes it into memories during sleep: This fact emphasizes how vital sleep is for cognitive function, specifically regarding learning and retaining new knowledge or experiences. It also highlights a potential link between dream content and personal growth, as individuals may incorporate newly acquired skills or insights within their dream narratives to further consolidate them into long-term memories.\n5. Dream content can be influenced by cultural factors, with different societies having unique themes or symbols recurring in dreams - for example, ancient Egyptians often had visions related to their belief system while modern Western cultures tend to have more personal and individualistic dream experiences: This fact highlights how culture shapes our subconscious mind during sleep. It also emphasizes that the content of our dreams is not universal but can vary based on cultural background, thus reflecting diverse perspect012ives and values within different societies.'

# %%
chain.get_graph().print_ascii()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 chain.get_graph().print_ascii()
#
# NameError: name 'chain' is not defined

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

model= ChatGroq( model_name="llama-3.3-70b-versatile",temperature=0.7)

# %%
chain=prompt1|model|parser|
