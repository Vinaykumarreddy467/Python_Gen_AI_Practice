# %%
pip -q install langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from dotenv import load_dotenv

load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
print(GROQ_API_KEY)
# Out:
# DUMMY_KEY_REDACTED

# %%
from langchain_groq import ChatGroq

#Initialize Groq LLM
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

# %%
response = llm.invoke("Suggest me a title of movie in hindi to watch")
response.content
# Out:
# 'एक अच्छी फिल्म का सुझाव देने के लिए, मैं आपको "दिलवाले दुल्हनिया ले जाएंगे" (Dilwale Dulhania Le Jayenge) की सलाह देता हूं। यह एक रोमांटिक फिल्म है जो शाहरुख खान और काजोल पर आधारित है। यह फिल्म 1995 में रिलीज़ हुई थी और यह अभी भी एक बहुत ही लोकप्रिय फिल्म है।\n\nइस फिल्म में, राज (शाहरुख खान) और सिमरन (काजोल) दो युवा हैं जो लंदन में मिलते हैं और प्यार में पड़ जाते हैं। लेकिन सिमरन के पिता ने उसकी शादी किसी और से तय कर दी है, जिससे राज और सिमरन को अपने प्यार को साबित करने के लिए संघर्ष करना पड़ता है।\n\nयह फिल्म आपको हंसाएगी, रुलाएगी और आपको प्यार के बारे में सोचने पर मजबूर करेगी। तो अगर आप एक अच्छी रोमांटिक फिल्म देखना चाहते हैं, तो "दिलवाले दुल्हनिया ले जाएंगे" जरूर देखें।'

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Italian"),
    HumanMessage("hi!"),
]
response=llm.invoke(messages)
response.content
# Out:
# 'Ciao!'

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Italian"),
    HumanMessage("hi!"),
]
response=llm.invoke(messages)

# %%
response.content
# Out:
# 'Ciao!'

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "hindi", "text": "what is your age"})

prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into hindi', additional_kwargs={}, response_metadata={}), HumanMessage(content='what is your age', additional_kwargs={}, response_metadata={})])

# %%
response=llm.invoke(prompt)

# %%
response.content
# Out:
# 'आपकी उम्र क्या है'

# %%
from langchain_core.prompts import ChatPromptTemplate

system_templete="you are a poet who whote poems in {language} tell a good poem to the user"

promp_templete=ChatPromptTemplate.from_messages([("system",system_templete),("user","{text}")])

prompt=prompt_template.invoke({"language":"hindi", "text": "poem on moon"})

response=llm.invoke(prompt)
response.content
# Out:
# 'चंद्रमा पर कविता:\n\nचंद्रमा की चांदनी रात में,\nतारों के साथ खेलती है साथ में।\nउसकी रोशनी से जगमगाता है आसमान,\nऔर धरती पर फैलता है प्यार का सम्मान।\n\nचंद्रमा की किरणें हमें आकर्षित करती हैं,\nऔर उसकी सुंदरता को हम निहारते हैं।\nउसकी गति से हमें प्रेरणा मिलती है,\nऔर उसकी शीतलता से हमें शांति मिलती है।\n\nचंद्रमा की पूर्णिमा की रात में,\nहम उसकी सुंदरता को देखते हैं।\nउसकी रोशनी से हमें राह दिखाती है,\nऔर उसकी मौजूदगी से हमें सुरक्षा मिलती है।\n\nचंद्रमा हमारे जीवन का हिस्सा है,\nऔर उसकी सुंदरता को हम कभी नहीं भूल सकते।\nउसकी रोशनी से हमें प्यार और शांति मिलती है,\nऔर उसकी मौजूदगी से हमें जीवन का अर्थ मिलता है।'
