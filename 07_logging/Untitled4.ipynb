# %%
pip install  logging
# Out:
# Requirement already satisfied: logging in /home/mikealson/anaconda3/lib/python3.13/site-packages (0.4.9.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging

logger=logging.getLogger(__name__)
file_handler=logging.FileHandler("apps.log")
console_handler=logging.StreamHandler()

formatter=logging.Formatter(" %(asctime)s - %(name)s -%(levelname)s -%(message)s")

file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# %%
lists=[1,2,3,4,6,7,8,5,9]
batch=2
for i in range(0,len(lists)-1,batch):
    if i<len(lists): print(lists[i]+lists[i+1],end=" ")
if len(lists)%2 ==1:
    print(lists[-1])
# Out:
# 3 7 13 13 9

# %%
lists=[1,2,3,4,6,7,8,5]
for i in range(0,len(lists)-1,2):
    print(lists[i]+lists[i+1])
# Out:
# 3
# 7
# 13
# 13
