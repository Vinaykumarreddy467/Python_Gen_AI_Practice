# %%
from fastapi import FastAPI

# %%
app = FastAPI()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 app = FastAPI()
#
# File ~/anaconda3/lib/python3.13/site-packages/fastapi/applications.py:896, in FastAPI.__init__(self, debug, routes, title, summary, description, version, openapi_url, openapi_tags, servers, dependencies, default_response_class, redirect_slashes, docs_url, redoc_url, swagger_ui_oauth2_redirect_url, swagger_ui_init_oauth, middleware, exception_handlers, on_startup, on_shutdown, lifespan, terms_of_service, contact, license_info, openapi_prefix, root_path, root_path_in_servers, responses, callbacks, webhooks, deprecated, include_in_schema, swagger_ui_parameters, generate_unique_id_function, separate_input_output_schemas, **extra)
#     878 if openapi_prefix:
#     879     logger.warning(
#     880         '"openapi_prefix" has been deprecated in favor of "root_path", which '
# ...

# %%
@app.get("/")
async def root():
    return {"message": "Hello World"}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 @app.get("/")
#       2 async def root():
#       3     return {"message": "Hello World"}
#
# NameError: name 'app' is not defined
