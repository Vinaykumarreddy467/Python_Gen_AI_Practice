# %%
# !pip install langchain-huggingface
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached tokenizers-0.23.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.5/671.5 kB 2.0 MB/s  0:00:00m ? eta -:--:--
# Using cached hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
# Using cached tokenizers-0.23.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [langchain-huggingface]/5 [huggingface-hub]
# ...

# %%
from langchain_huggingface import ChatHuggingFace

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 from openai import OpenAI
#       4 client = OpenAI(
#       5     base_url="https://router.huggingface.co/v1",
#       6     api_key=os.environ["HF_TOKEN"],
#       7 )
#       9 completion = client.chat.completions.create(
#      10     model="deepseek-ai/DeepSeek-V4-Pro:novita",
#      11     messages=[
#    (...)     16     ],
#      17 )
#
# ModuleNotFoundError: No module named 'openai'
