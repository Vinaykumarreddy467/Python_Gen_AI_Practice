# %%
#1. Create a set with the values 10, 20, 30, 40.
set={10, 20, 30, 40}

# %%
# 2. Print all elements of a set.
set
# Out:
# {10, 20, 30, 40}

# %%
# 3. Add the value 50 to a set.
set.add(50)
set
# Out:
# {10, 20, 30, 40, 50}

# %%
# 4. Remove the value 20 from a set.
set={10, 20, 30, 40}
set.remove(20)
set
# Out:
# {10, 30, 40}

# %%
# 5. Find the length of a set.
set={10, 20, 30, 40}
len(set)
# Out:
# 4

# %%
# 6. Check if 30 exists in a set.
set={10, 20, 30, 40}
if 30 in set:
    print("30 is in there in the set")
# Out:
# 30 is in there in the set

# %%
# 7. Create two sets and find their union.
set={10, 20, 30, 40}
set2={50, 60, 70, 80}
set.union(set2)
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80}

# %%
# 8. Create two sets and find their intersection.
set={10, 20, 30, 40}
set2={50, 60, 70, 80,20}
set.intersection(set2)
# Out:
# {20}

# %%
# 9. Find the difference between two sets.
et={10, 20, 30, 40}
set2={50, 60, 70, 80,20}
set.difference(set2)
# Out:
# {10, 30, 40}

# %%
# 10. Find the symmetric difference between two sets.
set={10, 20, 30, 40}
set2={50, 60, 70, 80,20}
set^set2
# Out:
# {10, 30, 40, 50, 60, 70, 80}

# %%
# 11. Clear all elements from a set.
set={10, 20, 30, 40}
set2={50, 60, 70, 80,20}
set.clear()
set
# Out:
# set()

# %%
# 12. Copy one set into another.
set={1,2,3,4,5}
set1=set.copy()
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
# 13. Convert a list with duplicate values into a set.
list=[1,2,3,4,5,6,7,56,4,3,23,2,3,4,2,1,4,5]
print(set(list))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 23, 56}

# %%
# 14. Find the maximum value in a set.
list ={1,2,3,4,5,6,7,56,4,3,23,2,3,4,2,1,4,5}
max(list)
# Out:
# 56

# %%
# 15. Find the minimum value in a set.
set={1,2,3,4,5,6,7,56,4,3,23,2,3,4,2,1,4,5}
min(set)
# Out:
# 1

# %%
# 16. Create a set of vowels and check whether a character is a vowel.
vowel="aeiouAEIOU"
set1=set(vowel.strip())
print(set1)
charect=input("enter the charactor: ")
if  charect in set1:
    print(f"{charect} is a vowel")
# Out:
# {'A', 'E', 'i', 'e', 'u', 'I', 'o', 'a', 'O', 'U'}
# enter the charactor:  a
# a is a vowel

# %%
# 17. Remove duplicate numbers from a list using sets.
list1=[1,2,3,4,5,6,7,56,4,3,23,2,3,4,2,1,4,5]
s=set(list1)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 23, 56}

# %%
# 18. Count the number of unique elements in a list.
list1=[1,2,3,4,5,6,7,56,4,3,23,2,3,4,2,1,4,5]
num=len(

# %%
# 19. Check whether one set is a subset of another.

# %%
# 20. Check whether two sets are disjoint.
