# %%
#1. Convert an Integer into Decimals. Int=10
num=70
f_num=float(num)
print(f_num)
#2. Convert String of Integers to Decimals. Str = '12345'
string="12345"
num=int(string)
print(type(num))
#3. Writing Fibonacci Series. n=5
def fib(n):
    a, b = 0, 1
    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b
    print()

fib(5)

#4.Find max number in list. [12,3,4,5,6,73,88,9]
list1=[12,3,4,5,6,73,88,9]
print(max(list1))
#5. Add two list together . [1,2,3] [4,5,6]
l1= [1,2,3]
l2=[4,5,6]
l3=l1+l2
print(l3)
#6.Addition using Lambda function. (3,7)
add=lambda a,b:print(a+b)
add(3,7)
#7. Count the number of occurrences of character in a String. word = 'programming' character = 'g'
word = 'programming'
ch='g'
print(word.count(ch))
#8.Check Palindrome number . 
number=1221
if str(number)==str(number)[::-1]:
    print(f"{number} is a palindrome")

#9. Print Data Type of variable :comp: and value assigned to it is '15',. comp ='15'
comp ='15'
print(type(comp))
#10. Print length of 'Python'
print(len("python"))
# Out:
# 70.0
# <class 'int'>
# 0 1 1 2 3
# 88
# [1, 2, 3, 4, 5, 6]
# 10
# 2
# 1221 is a palindrome
# <class 'str'>
# 6
