# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/mikealson/anaconda3/lib/python3.13/site-packages (2.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

data = np.random.rand(2, 3)
print(data.ndim)
# Out:
# 2

# %%
print(data.shape)
# Out:
# (2, 3)

# %%
print(data.ndim)
# Out:
# 2

# %%
data.shape
# Out:
# (2, 3)

# %%
py_list=[1,2,3]
print("multiplication", py_list*2)
# Out:
# multiplication [1, 2, 3, 1, 2, 3]

# %%
py_array=np.array([1,2,3])
print("multiplication", py_list*2)
# Out:
# multiplication [1, 2, 3, 1, 2, 3]

# %%
import time
start=time.time()

py_list=[i*2 for i in range(1000)]

print("time taken is :    ", time.time()-start)
# Out:
# time taken is :     0.4645864963531494

# %%
import time
start=time.time()

np_array=np.arange(1000)*2

print("time taken is :    ", time.time()-start)
# Out:
# time taken is :     0.0014121532440185547

# %%
np_array.ndim
# Out:
# 1
