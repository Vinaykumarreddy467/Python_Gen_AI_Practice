# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

data = np.random.rand(2, 3, 4)
print(data.ndim)
# Out:
# 3

# %%
print(data.shape)
# Out:
# (2, 3, 4)

# %%
print(data.ndim)
# Out:
# 3
